# %% [markdown]
# <a href="https://colab.research.google.com/github/dli10/college-rankings-forbes-2019/blob/main/Data_Scraping_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests 
req = requests.get("https://www.forbes.com/colleges/university-of-california-berkeley/?list=top-colleges&sh=4d9c19d85bd4")
req
type(req)
dir(req)
page=req.text
page
# Out:
# '<!DOCTYPE html><html lang="en"><head><title itemprop="headline">University of California, Berkeley</title><meta charset="UTF-8"><meta http-equiv="Content-Language" content="en_US"><link rel="shortcut icon" href="https://i.forbesimg.com/48X48-F.png"><link rel="canonical" href="https://www.forbes.com/colleges/university-of-california-berkeley/"><meta name="viewport" content="width=device-width,initial-scale=1,maximum-scale=5,minimum-scale=1,user-scalable=yes"><meta name="referrer" content="origin-when-cross-origin"><meta name="description" itemprop="description" content="University of California, Berkeley"><meta name="keywords" content="University of California, Berkeley"><meta property="og:site_name" content="Forbes"><meta property="og:title" content="University of California, Berkeley"><meta property="og:type" content="website"><meta property="og:url" content="https://www.forbes.com/colleges/university-of-california-berkeley/"><meta property="og:image" content="https://imageio.forbe
# ...

# %%
from bs4 import BeautifulSoup

# %%
soup = BeautifulSoup(page, 'html.parser')

# %%
soup
# Out:
# <!DOCTYPE html>
# ...

# %%
type(page)
# Out:
# str

# %%
type(soup)
# Out:
# bs4.BeautifulSoup

# %%
print(soup.prettify())

# %%
soup.title
# Out:
# <title itemprop="headline">University of California, Berkeley</title>

# %%
"title" in dir(soup)
# Out:
# False

# %%
soup.p

# %%
len(soup.find_all("p"))
# Out:
# 0

# %%
soup.table["website"]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-20-895dbd1f8f75> in <module>()
# ----> 1 soup.table["website"]
#
# TypeError: 'NoneType' object is not subscriptable

# %%
soup.find_all("table")[1].get("class")
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-21-61182349e769> in <module>()
# ----> 1 soup.find_all("table")[1].get("class")
#
# IndexError: list index out of range

# %%
table_html = str(soup.find("table", "wikitable"))

# %%
from IPython.core.display import HTML

HTML(table_html)
# Out:
# None
